# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# GTEx set incudes tissues/cell types in GTEx.

GTEx = {
    "Adipose_Subcutaneous",
    "Adipose_Visceral_Omentum",
    "Adrenal_Gland",
    "Artery_Aorta",
    "Artery_Coronary",
    "Artery_Tibial",
    "Bladder",
    "Brain_Amygdala",
    "Brain_Anterior_cingulate_cortex_BA24",
    "Brain_Caudate_basal_ganglia",
    "Brain_Cerebellar_Hemisphere",
    "Brain_Cerebellum_GTEx",
    "Brain_Cortex",
    "Brain_Frontal_Cortex_BA9",
    "Brain_Hippocampus",
    "Brain_Hypothalamus",
    "Brain_Nucleus_accumbens_basal_ganglia",
    "Brain_Putamen_basal_ganglia",
    "Brain_Spinal_cord_cervical_c1",
    "Brain_Substantia_nigra",
    "Breast_Mammary_Tissue",
    "Cells_EBV-transformed_lymphocytes",
    "Cells_Transformed_fibroblasts",
    "Cervix_Ectocervix",
    "Cervix_Endocervix",
    "Colon_Sigmoid",
    "Colon_Transverse",
    "Esophagus_Gastroesophageal_Junction",
    "Esophagus_Mucosa",
    "Esophagus_Muscularis",
    "Fallopian_Tube",
    "Heart_Atrial_Appendage",
    "Heart_Left_Ventricle",
    "Kidney_Cortex",
    "Liver_GTEx",
    "Lung_GTEx",
    "Minor_Salivary_Gland",
    "Muscle_Skeletal",
    "Nerve_Tibial",
    "Ovary_GTEx",
    "Pancreas_GTEx",
    "Pituitary",
    "Prostate",
    "Skin_Not_Sun_Exposed_Suprapubic",
    "Skin_Sun_Exposed_Lower_leg",
    "Small_Intestine_Terminal_Ileum",
    "Spleen_GTEx",
    "Stomach_GTEx",
    "Testis",
    "Thyroid_GTEx",
    "Uterus_GTEx",
    "Vagina",
    "Whole_Blood",
}

# groups = hematopoietic + epithelial + stem + muscle_fib + endothelial

groups = [
    "myotube",
    "HSMM",
    "melanocyte_of_skin",
    "Penis_Foreskin_Fibroblast_Primary_Cells_skin01",
    "Penis_Foreskin_Fibroblast_Primary_Cells_skin02",
    "Penis_Foreskin_Melanocyte_Primary_Cells_skin01",
    "HUVEC",
    "lung_microvascular_endothelial_cell",
    "dermis_microvascular_lymphatic_vessel_endothelial_cell",
    "dermis_lymphatic_vessel_endothelial_cell",
    "endothelial_cell_of_umbilical_vein",
    "dermis_blood_vessel_endothelial_cell",
    "mammary_microvascular_endothelial_cell",
    "endometrial_microvascular_endothelial_cell",
    "pulmonary_artery_endothelial_cell",
    "thoracic_aorta_endothelial_cell",
    "epithelial_cell_of_umbilical_artery",
    "vein_endothelial_cell",
    "bladder_microvascular_endothelial_cell",
    "endothelial_cell_of_coronary_artery",
    "myometrial_cell",
    "fibroblast_of_arm",
    "LHCN-M2",
    "glomerular_endothelial_cell",
    "bronchial_fibroblast",
    "uterine_smooth_muscle_cell",
    "smooth_muscle_cell_of_trachea",
    "smooth_muscle_cell_of_the_umbilical_artery",
    "fibroblast_of_lung",
    "regular_cardiac_myocyte",
    "articular_chondrocyte_of_knee_joint",
    "cardiac_atrium_fibroblast",
    "skeletal_muscle_satellite_cell",
    "pericyte_cell",
    "aortic_smooth_muscle_cell",
    "cardiac_ventricle_fibroblast",
    "skeletal_muscle_myoblast",
    "fibroblast_of_villous_mesenchyme",
    "NHLF",
    "osteoblast",
    "bronchial_smooth_muscle_cell",
    "smooth_muscle_cell_of_bladder",
    "smooth_muscle_cell_of_the_pulmonary_artery",
    "H1_Derived_Mesenchymal_Stem_Cells",
    "pericardium_fibroblast",
    "smooth_muscle_cell_of_the_coronary_artery",
    "hair_follicle_dermal_papilla_cell",
    "fibroblast_of_dermis",
    "fibroblast_of_the_aortic_adventitia",
    "H4",
    "epithelial_cell_of_alveolus_of_lung",
    "hESC_Derived_CD56+_Mesoderm_Cultured_Cells",
    "Neurosphere_Cultured_Cells_Ganglionic_Eminence_Derived",
    "Neurosphere_Cultured_Cells_Cortex_Derived",
    "neural_progenitor_cell",
    "bipolar_spindle_neuron",
    "H1_Derived_Neuronal_Progenitor_Cultured_Cells",
    "hESC_Derived_CD56+_Ectoderm_Cultured_Cells",
    "hESC_Derived_CD184+_Endoderm_Cultured_Cells",
    "HUES64_Cell_Line",
    "H1_Cell_Line",
    "4star",
    "H1_BMP4_Derived_Mesendoderm_Cultured_Cells",
    "H7-hESC",
    "induced_pluripotent_stem_cell",
    "H1_BMP4_Derived_Trophoblast_Cultured_Cells",
    "Breast_Myoepithelial_Cells",
    "hepatocyte",
    "smooth_muscle_cell",
    "mesangial_cell",
    "kidney_epithelial_cell",
    "epithelial_cell_of_proximal_tubule",
    "renal_cortical_epithelial_cell",
    "hair_follicular_keratinocyte",
    "mammary_epithelial_cell",
    "airway_epithelial_cell",
    "tracheal_epithelial_cell",
    "human_nasal_epithelial_cells",
    "bronchial_epithelial_cell",
    "keratinocyte",
    "Penis_Foreskin_Keratinocyte_Primary_Cells_skin02",
    "HMEC",
    "NHEK",
    "Breast_vHMEC",
    "Penis_Foreskin_Keratinocyte_Primary_Cells_skin03",
    "placental_epithelial_cell",
    "Penis_Foreskin_Melanocyte_Primary_Cells_skin03",
    "GM12878_Roadmap",
    "hematopoietic_multipotent_progenitor_cell",
    "Mobilized_CD34_Primary_Cells_Female",
    "CD4_Memory_Primary_Cells",
    "CD4_Naive_Primary_Cells",
    "CD8_Naive_Primary_Cells",
    "Peripheral_Blood_Mononuclear_Primary_Cells",
]

# %%
# Read the observed/real gene expression profiles of the plotted cells.
# "geneanno.exp_noidx_renamed.csv" is similar to "geneanno.exp.csv" which is provided by the ExPecto author, but we delete the redundant fist column and label remaining columns as new names. The reason is that the original names of tissues/cells in "./resources/modellist" and "./resources/geneanno.exp.csv" in the ExPecto repository are not consistent.
observed = pd.read_csv("geneanno.exp_noidx_renamed.csv", usecols=groups)
observed
# Out:
#        cardiac_ventricle_fibroblast  hair_follicular_keratinocyte  \
# 0                             9.990                         9.735
# 1                             0.030                         0.000
# 2                            18.570                        44.240
# 3                             1.955                         2.845
# 4                             1.820                         8.810
# ...                             ...                           ...
# 24334                         0.000                         0.000
# 24335                         0.000                         0.395
# 24336                         0.000                         0.000
# 24337                         0.000                         0.000
# 24338                         0.010                         0.000
#
#        airway_epithelial_cell  epithelial_cell_of_proximal_tubule  \
# 0                      12.610                              27.635
# ...

# %%
# Add the additional "ave" column that contains the average expression level cross different cells for each gene.
# "A pseudocount was added before log transformation (0.01, except for 0.0001 for GTEx tissues (which were averaged across individuals) due to high coverage from pooling multiple samples)" cited from the paper.
for cell in set(observed.columns):
    if cell in GTEx:
        observed[cell] = observed[cell] + 0.0001
    else:
        observed[cell] = observed[cell] + 0.01
observed["ave"] = observed.mean(axis=1)
observed
# Out:
#        cardiac_ventricle_fibroblast  hair_follicular_keratinocyte  \
# 0                            10.000                         9.745
# 1                             0.040                         0.010
# 2                            18.580                        44.250
# 3                             1.965                         2.855
# 4                             1.830                         8.820
# ...                             ...                           ...
# 24334                         0.010                         0.010
# 24335                         0.010                         0.405
# 24336                         0.010                         0.010
# 24337                         0.010                         0.010
# 24338                         0.020                         0.010
#
#        airway_epithelial_cell  epithelial_cell_of_proximal_tubule  \
# 0                      12.620                              27.645
# ...

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.9, eta = 0.001

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.001.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.001.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                 1.740604    2.498658
# 1                                 0.228258    0.259279
# 2                                24.793240   28.484253
# 3                                16.328028   20.332951
# 4                                 7.933553    8.950422
# ...                                    ...         ...
# 24334                             0.102673    0.159604
# 24335                             0.369306    0.379908
# 24336                             0.240199    0.252588
# 24337                             0.123248    0.111709
# 24338                             0.201275    0.259622
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        1.284993                  1.259902
# 1                                        0.249960                  0.215584
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

# %%
correlation
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.057685  0.109836  0.120165  0.113219  0.149557  0.141241  0.165322
# 1   0.082168  0.136116  0.148467  0.140856  0.177025  0.144736  0.219233
# 2   0.068579  0.148438  0.162340  0.149376  0.212306  0.177326  0.234492
# 3   0.096074  0.135015  0.139933  0.130665  0.173314  0.193840  0.116756
# 4   0.129007  0.143691  0.143191  0.138120  0.157031  0.214535  0.057960
# ..       ...       ...       ...       ...       ...       ...       ...
# 89  0.166653  0.252816  0.265196  0.252452  0.319028  0.284613  0.308291
# 90  0.308989  0.368072  0.374889  0.371615  0.408905  0.371450  0.334099
# 91  0.330709  0.394290  0.400473  0.393920  0.431440  0.398816  0.344057
# 92  0.322569  0.381635  0.387276  0.381984  0.417845  0.386889  0.329257
# 93  0.348099  0.378248  0.379624  0.382175  0.401315  0.397793  0.287482
#
#           7         8         9   ...        84        85        86        87  \
# ...

# %%
ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.9, eta = 0.01

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.01.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.01.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                 2.232507    3.645699
# 1                                 0.077177    0.096197
# 2                                20.106791   27.766741
# 3                                14.117396   14.299525
# 4                                 6.480915    6.247600
# ...                                    ...         ...
# 24334                             0.034856    0.058673
# 24335                             0.088317    0.087099
# 24336                             0.086572    0.088730
# 24337                             0.060460    0.040023
# 24338                             0.114248    0.180404
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        1.414546                  1.448323
# 1                                        0.084959                  0.074922
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )
ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.9, eta = 0.1

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.1.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta0.1.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                 3.181461    5.061991
# 1                                 0.056736    0.073119
# 2                                18.767896   25.727605
# 3                                17.260713   17.289676
# 4                                 6.813773    6.432493
# ...                                    ...         ...
# 24334                             0.029276    0.048609
# 24335                             0.057513    0.057000
# 24336                             0.064377    0.063947
# 24337                             0.061794    0.039439
# 24338                             0.090970    0.148716
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        1.964450                  2.043249
# 1                                        0.061934                  0.054725
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.9, eta = 1

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta1.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.9_eta1.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                 5.073222    8.096490
# 1                                 0.035188    0.045097
# 2                                17.954097   24.498578
# 3                                25.450335   25.400234
# 4                                 8.162054    7.694528
# ...                                    ...         ...
# 24334                             0.025454    0.042211
# 24335                             0.024202    0.023829
# 24336                             0.041219    0.040777
# 24337                             0.055638    0.035652
# 24338                             0.049082    0.079860
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        3.156394                  3.318717
# 1                                        0.037638                  0.033317
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.7.post4, eta = 0.001

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.001.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.001.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                 6.652987    9.012955
# 1                                 0.025444    0.034470
# 2                                29.479529   46.728384
# 3                                30.246657   27.432540
# 4                                10.001574   10.823107
# ...                                    ...         ...
# 24334                             0.016226    0.023304
# 24335                             0.023770    0.018778
# 24336                             0.043971    0.032973
# 24337                             0.070849    0.037622
# 24338                             0.079727    0.151958
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        3.387005                  3.723180
# 1                                        0.026094                  0.024779
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.7.post4, eta = 0.01

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.01.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.01.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                12.121917   17.840364
# 1                                 0.027554    0.035793
# 2                                28.533783   41.622298
# 3                                28.575966   38.633553
# 4                                10.004603   13.939427
# ...                                    ...         ...
# 24334                             0.012287    0.017866
# 24335                             0.014478    0.012103
# 24336                             0.031927    0.017791
# 24337                             0.061526    0.027152
# 24338                             0.046829    0.151001
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        6.173297                  7.656027
# 1                                        0.029266                  0.027705
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models trained by ourselves: xgboost = v0.7.post4, eta = 0.1

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.01.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_plotted_our_xg0.7_eta0.1.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#        Mobilized_CD34_Primary_Cells_Female  hepatocyte  \
# 0                                12.121917   17.840364
# 1                                 0.027554    0.035793
# 2                                28.533783   41.622298
# 3                                28.575966   38.633553
# 4                                10.004603   13.939427
# ...                                    ...         ...
# 24334                             0.012287    0.017866
# 24335                             0.014478    0.012103
# 24336                             0.031927    0.017791
# 24337                             0.061526    0.027152
# 24338                             0.046829    0.151001
#
#        Peripheral_Blood_Mononuclear_Primary_Cells  CD4_Memory_Primary_Cells  \
# 0                                        6.173297                  7.656027
# 1                                        0.029266                  0.027705
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models provided by the author: xgboost = v0.7.post4 (oldFormat == True)

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_all_provided_xg0.7.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_all_provided_xg0.7.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#            4star  Breast_Myoepithelial_Cells  Breast_vHMEC  \
# 0      12.180728                   12.368881     10.316205
# 1       0.020806                    0.028148      0.030611
# 2      29.752229                   39.840361     21.805410
# 3      18.635420                   12.694895     14.193351
# 4       7.904988                    4.325867      6.558884
# ...          ...                         ...           ...
# 24334   0.018610                    0.018056      0.009705
# 24335   0.025789                    0.012369      0.016205
# 24336   0.018980                    0.026852      0.038748
# 24337   0.047591                    0.043895      0.060265
# 24338   0.060085                    0.045883      0.037813
#
#        CD4_Memory_Primary_Cells  CD4_Naive_Primary_Cells  \
# 0                      7.650635                 8.372103
# 1                      0.028358                 0.028297
# 2                     20.832058                19.709698
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %% [markdown]
# ***
# # Models provided by the author: xgboost = v0.9 (oldFormat == True)

# %%
# Read the predicted gene expression profiles of the plotted cells.
predicted = pd.read_csv(
    "gene_exp_predict/Exp_all_provided_xg0.9.csv", usecols=groups
)

# Because the predicted values are ones after log transformation, we need to get the values before log transformation (RPKM), in order to calculate the predicted average expression level cross different cells for each gene.
predicted = np.exp(predicted)
predicted["ave"] = predicted.mean(axis=1)

# Record the seqname and type of each gene for further filtration.
seq_type = pd.read_csv(
    "gene_exp_predict/Exp_all_provided_xg0.9.csv", usecols=["seqnames", "type"]
)
predicted
# Out:
#            4star  Breast_Myoepithelial_Cells  Breast_vHMEC  \
# 0      12.180728                   12.368881     10.316205
# 1       0.020806                    0.028148      0.030611
# 2      29.752229                   39.840361     21.805410
# 3      18.635420                   12.694895     14.193351
# 4       7.904988                    4.325867      6.558884
# ...          ...                         ...           ...
# 24334   0.018610                    0.018056      0.009705
# 24335   0.025789                    0.012369      0.016205
# 24336   0.018980                    0.026852      0.038748
# 24337   0.047591                    0.043895      0.060265
# 24338   0.060085                    0.045883      0.037813
#
#        CD4_Memory_Primary_Cells  CD4_Naive_Primary_Cells  \
# 0                      7.650635                 8.372103
# 1                      0.028358                 0.028297
# 2                     20.832058                19.709698
# ...

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="pearson"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)

# %%
# Calculate the pearson correlation between the observed and predicted values on the held out genes.
correlation = pd.DataFrame(np.zeros((94, 94)))
for i in range(94):
    for j in range(94):
        row = groups[i]
        column = groups[93 - j]
        combine = pd.concat(
            [
                seq_type,
                np.log(observed[row]) - np.log(observed["ave"]),
                np.log(predicted[column]) - np.log(predicted["ave"]),
            ],
            axis=1,
            ignore_index=False,
        )
        combine = combine[combine.seqnames == "chr8"]
        combine = combine[combine.type != "rRNA"]
        correlation.iloc[i, j] = combine.iloc[:, 2].corr(
            combine.iloc[:, 3], method="spearman"
        )

ax = sns.heatmap(correlation, center=0, xticklabels=False, yticklabels=False)
